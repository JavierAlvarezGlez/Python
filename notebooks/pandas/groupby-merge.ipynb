# %% [markdown]
# # Agregación y mergeo de dataframes

# %% [markdown]
# En esta sección vamos a introducir dis tipo de operaciones muy comunes cuando trabajamos con dataframes, inspiradas en el lenguaje sql: agregaciones con `groupby` y mergeos con `merge`. La primera nos permitirá aplicar funciones de agregación a subconjuntos de nuestro dataframe y la segunda hacer que varios dataframes interactúen cuando tienen una o varias claves en común

# %% [markdown]
# ## Agregaciones

# %% [markdown]
# Cargamos un dataset sobre una encuesta realizada a programadores de python

# %%
import pandas as pd
import numpy as np

url = "https://github.com/mattharrison/datasets/raw/master/data/2020-jetbrains-python-survey.csv"
jb = pd.read_csv(url)
# Out:
# <ipython-input-1-2e3c5a33e610>:5: DtypeWarning: Columns (152) have mixed types. Specify dtype option on import or set low_memory=False.
#   jb = pd.read_csv(url)

# %%
jb.columns
# Out:
# Index(['is.python.main', 'other.lang.None', 'other.lang.Java',
#        'other.lang.JavaScript', 'other.lang.C/C++', 'other.lang.PHP',
#        'other.lang.C#', 'other.lang.Ruby', 'other.lang.Bash / Shell',
#        'other.lang.Objective-C',
#        ...
#        'job.role.Technical support', 'job.role.Data analyst',
#        'job.role.Business analyst', 'job.role.Team lead',
#        'job.role.Product manager', 'job.role.CIO / CEO / CTO',
#        'job.role.Systems analyst', 'job.role.Other', 'age', 'country.live'],
#       dtype='object', length=264)

# %% [markdown]
# Seleccionamos algunas de las columnas y realizamos un pipeline de transformaciones

# %%
cols = [
    'age',
    'are.you.datascientist',
    'company.size',
    'country.live',
    'employment.status',
    'first.learn.about.main.ide',
    'how.often.use.main.ide',
    'ide.main',
    'is.python.main',
    'job.team',
    'main.purposes',
    'missing.features.main.ide',
    'nps.main.ide',
    'python.years',
    'python2.version.most',
    'python3.version.most',
    'several.projects',
    'team.size',
    'use.python.most',
    'years.of.coding'
]

# %%
jb2 = (jb
    [cols]
    .rename(columns=lambda c: c.replace('.', '_')) #renombrar las columnas
    .assign( # realizar transformaciones en las columnas usado argumentos de python
        age=lambda df_: df_.age.str.slice(0,2).astype(float).astype('Int64'),
        are_you_datascientist=lambda df_: df_.are_you_datascientist.replace({'Yes': True, 'No': False, np.nan: False}),
        company_size=lambda df_: df_.company_size.replace({
            'Just me': 1,
            'Not sure': np.nan,
            'More than 5,000': 5000,
            '2–10': 2,
            '11–50':11,
            '51–500': 51,
            '501–1,000':501,
            '1,001–5,000':1001
        }).astype('Int64'),
        country_live=lambda df_: df_.country_live.astype('category'),
        employment_status=lambda df_: df_.employment_status.fillna('Other').astype('category'),
        is_python_main=lambda df_: df_.is_python_main.astype('category'),
        team_size=lambda df_: df_.team_size.str.split(r'-', n=1, expand=True).iloc[:,0].replace('More than 40 people', 41).where(df_.company_size!=1, 1).astype(float),
        years_of_coding=lambda df_: df_.years_of_coding.replace('Less than 1 year', .5).str.extract(r'(\d+)').astype(float),
        python_years=lambda df_: df_.python_years.replace('Less than 1 year', .5).str.extract(r'(\d+)').astype(float),
        python3_ver=lambda df_: df_.python3_version_most.str.replace('_', '.').str.extract(r'(\d\.\d)').astype(float),
        use_python_most=lambda df_: df_.use_python_most.fillna('Unknown')
    ).drop(columns=['python2_version_most'])
)

# %% [markdown]
# En esta serie de transformaciones estamos usando el método `assign`, que nos permite mediante una serie de argumentos nombrados actualizar/crear columnas de un dataframe. Si se emplean funciones para describir las nuevas columnas, `assign` utiliza el estado del dataframe en el que se evalúa cada una, de modo que podemos usar columnas que hayan sido actualizadas en argumentos anteriores en lugar de usar varias veces `assign`.

# %%
jb2
# Out:
#         age are_you_datascientist  company_size        country_live  \
# 0        30                 False             1                 NaN
# 1        21                  True          5000               India
# 2        30                 False          5000       United States
# 3      <NA>                 False          <NA>                 NaN
# 4        21                 False          <NA>               Italy
# ...     ...                   ...           ...                 ...
# 54457    21                 False             2  Russian Federation
# 54458  <NA>                 False          <NA>                 NaN
# 54459    21                 False             1  Russian Federation
# 54460    30                  True            51               Spain
# 54461    21                 False            11             Algeria
#
#                                        employment_status  \
# 0         Partially employed by a company / organization
# 1             Fully employed by a company / organization
# 2             Fully employed by a company / organization
# 3                                                  Other
# 4                                                Student
# ...                                                  ...
# 54457         Fully employed by a company / organization
# 54458                                              Other
# 54459  Self-employed (a person earning income directl...
# 54460         Fully employed by a company / organization
# 54461         Fully employed by a company / organization
#
#                       first_learn_about_main_ide how_often_use_main_ide  \
# 0                        Conference / User Group                 Weekly
# 1                            School / University                  Daily
# 2                             Friend / Colleague                  Daily
# 3                             Friend / Colleague                  Daily
# 4                                 Search engines                  Daily
# ...                                          ...                    ...
# 54457                        School / University                  Daily
# 54458                                        NaN                    NaN
# 54459                         Friend / Colleague                  Daily
# 54460                             Search engines                  Daily
# 54461   Online learning platform / Online course                  Daily
#
#                            ide_main is_python_main  \
# 0         PyCharm Community Edition            Yes
# 1                           VS Code            Yes
# 2                               Vim            Yes
# 3      PyCharm Professional Edition            Yes
# 4                           VS Code            Yes
# ...                             ...            ...
# 54457                           Vim            Yes
# 54458                           NaN            Yes
# 54459  PyCharm Professional Edition            Yes
# 54460                         Other            Yes
# 54461                       VS Code            Yes
#
#                                         job_team  \
# 0      Work as an external consultant or trainer
# 1                                 Work in a team
# 2      Work on your own project(s) independently
# 3                                            NaN
# 4      Work on your own project(s) independently
# ...                                          ...
# 54457  Work on your own project(s) independently
# 54458                                        NaN
# 54459                             Work in a team
# 54460  Work on your own project(s) independently
# 54461                             Work in a team
#
#                                      main_purposes  \
# 0                                         For work
# 1                       Both for work and personal
# 2                       Both for work and personal
# 3                       Both for work and personal
# 4      For personal, educational  or side projects
# ...                                            ...
# 54457                   Both for work and personal
# 54458                   Both for work and personal
# 54459                   Both for work and personal
# 54460                   Both for work and personal
# 54461                   Both for work and personal
#
#                 missing_features_main_ide  nps_main_ide  python_years  \
# 0      No, it has all the features I need           3.0           3.0
# 1      No, it has all the features I need           8.0           3.0
# 2      No, it has all the features I need          10.0           3.0
# 3                      Yes – Please list:          10.0          11.0
# 4      No, it has all the features I need          10.0           1.0
# ...                                   ...           ...           ...
# 54457  No, it has all the features I need          10.0           6.0
# 54458                                 NaN           NaN           3.0
# 54459  No, it has all the features I need          10.0           3.0
# 54460                  Yes – Please list:           3.0           6.0
# 54461  No, it has all the features I need          10.0           1.0
#
#       python3_version_most                                   several_projects  \
# 0               Python 3_7             Yes, I work on many different projects
# 1               Python 3_6  Yes, I work on one main and several side projects
# 2               Python 3_6  Yes, I work on one main and several side projects
# 3               Python 3_8             Yes, I work on many different projects
# 4               Python 3_8  Yes, I work on one main and several side projects
# ...                    ...                                                ...
# 54457           Python 3_6             Yes, I work on many different projects
# 54458           Python 3_7                                                NaN
# 54459           Python 3_7             Yes, I work on many different projects
# 54460           Python 3_7             Yes, I work on many different projects
# 54461           Python 3_8             Yes, I work on many different projects
#
#        team_size                                    use_python_most  \
# 0            1.0                                            Unknown
# 1            2.0                               Software prototyping
# 2            NaN  DevOps / System administration / Writing autom...
# 3            1.0                                    Web development
# 4            1.0                                    Web development
# ...          ...                                                ...
# 54457        NaN                                      Data analysis
# 54458        1.0                                    Web development
# 54459        1.0                                    Web development
# 54460        NaN                                      Data analysis
# 54461        2.0                                            Unknown
#
#        years_of_coding  python3_ver
# 0                  1.0          3.7
# 1                  3.0          3.6
# 2                  3.0          3.6
# 3                 11.0          3.8
# 4                  NaN          3.8
# ...                ...          ...
# 54457              1.0          3.6
# 54458              1.0          3.7
# 54459              6.0          3.7
# 54460              3.0          3.7
# 54461              1.0          3.8
#
# [54462 rows x 20 columns]

# %% [markdown]
# Una de las formas que existen para realizar agregaciones en pandas es mediante el objeto `DataFrameGroupBy`, seguido siempre de una selección de columna(s) y una o varias funciones de agregación.

# %%
gb = jb2.groupby(["country_live"])  # agrupacion de county_live

# %%
type(gb)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
gb["age"]

# %% [markdown]
# Podemos aplicar los métodos de agregación que hemos visto para numpy y pandas a los objetos de tipo `_GroupBy`

# %%
gb["age"].mean()
# Out:
# country_live
# Algeria          27.528736
# Argentina         29.65641
# Armenia          25.967742
# Australia        32.527578
# Austria          29.914894
#                    ...
# United States    32.023162
# Uruguay           29.30303
# Uzbekistan       23.290323
# Venezuela        27.909091
# Viet Nam         24.421053
# Name: age, Length: 76, dtype: Float64

# %% [markdown]
# Podemos agregar usando varias columnas

# %%
s = (
    jb2
    .groupby(["country_live", "employment_status"])
    .age
    .mean()
)
s
# Out:
# country_live  employment_status
# Algeria       Freelancer (a person pursuing a profession without a long-term commitment to any one employer)    33.285714
#               Fully employed by a company / organization                                                        28.344828
#               Other                                                                                             43.333333
#               Partially employed by a company / organization                                                    25.181818
#               Retired                                                                                                60.0
#                                                                                                                   ...
# Viet Nam      Partially employed by a company / organization                                                         23.4
#               Retired                                                                                                <NA>
#               Self-employed (a person earning income directly from one's own business, trade, or profession)         35.5
#               Student                                                                                           19.384615
#               Working student                                                                                   24.571429
# Name: age, Length: 608, dtype: Float64

# %%
s.loc["Spain"]
# Out:
# employment_status
# Freelancer (a person pursuing a profession without a long-term commitment to any one employer)    34.310345
# Fully employed by a company / organization                                                        30.421687
# Other                                                                                                  33.2
# Partially employed by a company / organization                                                    28.909091
# Retired                                                                                               56.25
# Self-employed (a person earning income directly from one's own business, trade, or profession)    34.952381
# Student                                                                                           20.291667
# Working student                                                                                   24.294118
# Name: age, dtype: Float64

# %%
s.loc[("Spain", "Student")]
# Out:
# 20.291666666666668

# %% [markdown]
# Para convertir el último nivel del índice en una columnas usamos el método `unstack`

# %%
s.unstack()
# Out:
# employment_status  Freelancer (a person pursuing a profession without a long-term commitment to any one employer)  \
# country_live
# Algeria                                                    33.285714
# Argentina                                                  34.954545
# Armenia                                                         30.0
# Australia                                                  30.818182
# Austria                                                    35.857143
# ...                                                              ...
# United States                                              34.318471
# Uruguay                                                         30.0
# Uzbekistan                                                      36.0
# Venezuela                                                  29.888889
# Viet Nam                                                        28.8
#
# employment_status  Fully employed by a company / organization      Other  \
# country_live
# Algeria                                             28.344828  43.333333
# Argentina                                           30.209524       40.0
# Armenia                                             23.842105       60.0
# Australia                                           33.074468       33.1
# Austria                                             31.318182       30.0
# ...                                                       ...        ...
# United States                                       32.343223  35.534884
# Uruguay                                             28.909091       <NA>
# Uzbekistan                                             22.125       29.0
# Venezuela                                           27.826087       30.5
# Viet Nam                                            23.025641       60.0
#
# employment_status  Partially employed by a company / organization    Retired  \
# country_live
# Algeria                                                 25.181818       60.0
# Argentina                                                   30.25       55.0
# Armenia                                                      24.0       40.0
# Australia                                                    32.0  48.285714
# Austria                                                      29.0       60.0
# ...                                                           ...        ...
# United States                                           25.894737  54.920635
# Uruguay                                                      36.2       <NA>
# Uzbekistan                                                   21.0       <NA>
# Venezuela                                                    26.8       55.0
# Viet Nam                                                     23.4       <NA>
#
# employment_status  Self-employed (a person earning income directly from one's own business, trade, or profession)  \
# country_live
# Algeria                                                    28.411765
# Argentina                                                  29.571429
# Armenia                                                         24.0
# Australia                                                   39.21875
# Austria                                                    34.615385
# ...                                                              ...
# United States                                              38.446512
# Uruguay                                                         30.0
# Uzbekistan                                                      30.5
# Venezuela                                                      28.75
# Viet Nam                                                        35.5
#
# employment_status    Student  Working student
# country_live
# Algeria              20.4375             21.0
# Argentina          22.913043             23.2
# Armenia                 <NA>             <NA>
# Australia          24.828571        22.470588
# Austria            20.842105          23.8125
# ...                      ...              ...
# United States      21.947791         22.89375
# Uruguay                 20.0             <NA>
# Uzbekistan              19.0             21.0
# Venezuela          20.454545        28.833333
# Viet Nam           19.384615        24.571429
#
# [76 rows x 8 columns]

# %% [markdown]
# También podemos usar una función de agregación definida por nosotros usando el método `agg`

# %%
def per_emacs(s):
    return s.str.contains("Emacs").sum() / len(s) * 100
# Esto coje las personas q usan emacs, los suma y los divide entre su dimension

# %%
(
    jb2
    .groupby("country_live")
    .ide_main
    .agg(per_emacs)
)
# Out:
# country_live
# Algeria          0.000000
# Argentina        4.102564
# Armenia          0.000000
# Australia        2.877698
# Austria          1.595745
#                    ...
# United States    4.025157
# Uruguay          0.000000
# Uzbekistan       0.000000
# Venezuela        0.000000
# Viet Nam         0.000000
# Name: ide_main, Length: 76, dtype: float64

# %% [markdown]
# Podemos realizar agregaciones múltiples

# %%
(
    jb2
    .groupby("country_live")
    .age
    .agg([min, max])
)
# Out:
#                min  max
# country_live
# Algeria         18   60
# Argentina       18   60
# Armenia         18   60
# Australia       18   60
# Austria         18   60
# ...            ...  ...
# United States   18   60
# Uruguay         18   60
# Uzbekistan      18   60
# Venezuela       18   60
# Viet Nam        18   60
#
# [76 rows x 2 columns]

# %% [markdown]
# Finalmente, también se puede hacer múltiples agregaciones para cada columna

# %%
(
    jb2
    .groupby("country_live")
    .agg({
        "age": ["min", "max"],
        "team_size": "mean"
    })
)
# Out:
#               age     team_size
#               min max      mean
# country_live
# Algeria        18  60  2.428571
# Argentina      18  60  3.192053
# Armenia        18  60  6.076923
# Australia      18  60  2.710884
# Austria        18  60  2.448000
# ...            ..  ..       ...
# United States  18  60  3.391337
# Uruguay        18  60  4.692308
# Uzbekistan     18  60  1.160000
# Venezuela      18  60  1.812500
# Viet Nam       18  60  3.285714
#
# [76 rows x 3 columns]

# %% [markdown]
# combo final:

# %%
(
    jb2
    .groupby(["country_live", "employment_status"])
    .agg({
        "age": ["min", "max"],
        "team_size": "mean"
    })
)
# Out:
#                                                                   age        \
#                                                                   min   max
# country_live employment_status
# Algeria      Freelancer (a person pursuing a profession with...    21    60
#              Fully employed by a company / organization            18    60
#              Other                                                 30    50
#              Partially employed by a company / organization        18    40
#              Retired                                               60    60
# ...                                                               ...   ...
# Viet Nam     Partially employed by a company / organization        18    30
#              Retired                                             <NA>  <NA>
#              Self-employed (a person earning income directly...    21    60
#              Student                                               18    21
#              Working student                                       18    40
#
#                                                                 team_size
#                                                                      mean
# country_live employment_status
# Algeria      Freelancer (a person pursuing a profession with...  1.000000
#              Fully employed by a company / organization          2.750000
#              Other                                               1.000000
#              Partially employed by a company / organization      5.833333
#              Retired                                             1.000000
# ...                                                                   ...
# Viet Nam     Partially employed by a company / organization      5.666667
#              Retired                                                  NaN
#              Self-employed (a person earning income directly...  1.000000
#              Student                                             1.000000
#              Working student                                     1.333333
#
# [608 rows x 3 columns]

# %% [markdown]
# ## Mergeo

# %% [markdown]
# Hasta ahora hemos tratado los dataframes de forma independiente, pero vamos a ver a continuación como juntas varios dataframes de diferentes modos

# %%
df1 = pd.DataFrame(
    {
        'name': ['John', 'George', 'Ringo'],
        'color': ['Blue', 'Blue', 'Purple']
    }
)
df2 = pd.DataFrame(
    {
        'name': ['Paul', 'George', 'Ringo'],
        'carcolor': ['Red', 'Blue', np.nan]
    },
    index=[3, 1, 2]
)

# %%
df1
# Out:
#      name   color
# 0    John    Blue
# 1  George    Blue
# 2   Ringo  Purple

# %%
df2
# Out:
#      name carcolor
# 3    Paul      Red
# 1  George     Blue
# 2   Ringo      NaN

# %% [markdown]
# El método `merge` realiza un *inner join* por defecto

# %%
df1.merge(df2)  # coge las que son comunes en ambos y los compara (intersecion)
# Out:
#      name   color carcolor
# 0  George    Blue     Blue
# 1   Ringo  Purple      NaN

# %% [markdown]
# Pero existen otros tipos de merge utilizados usualmente al gestionar en bases de datos

# %%
df1.merge(df2, how="outer") # El outher es la union de ambas
# Out:
#      name   color carcolor
# 0    John    Blue      NaN
# 1  George    Blue     Blue
# 2   Ringo  Purple      NaN
# 3    Paul     NaN      Red

# %%
df1.merge(df2, how="left")
# Out:
#      name   color carcolor
# 0    John    Blue      NaN
# 1  George    Blue     Blue
# 2   Ringo  Purple      NaN

# %% [markdown]
# Por defecto, pandas cruza por aquellas columans que tengan el mismo nombre. Sin embargo a veces tenemos que pasarle el nombre de las columas, para ello tenemos los atributos `on`, `left_on` y `right_on`

# %%
df1.merge(df2, how="right", left_on="color", right_on="carcolor")
# Esto es para especificarles las columnas por las que quiere unir
# Out:
#    name_x color  name_y carcolor
# 0     NaN   NaN    Paul      Red
# 1    John  Blue  George     Blue
# 2  George  Blue  George     Blue
# 3     NaN   NaN   Ringo      NaN

# %% [markdown]
# Pandas incorpora también el método `join`, que es similar a `merge` pero opera con los ínidices de los dataframes, no las columnas.

# %% [markdown]
# Existe pandas str y pandas date. Son de las mas importantes de pandas
